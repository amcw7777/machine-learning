# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
data_train = pd.read_csv("./train.cvs")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-1ed41c1b9e0a> in <module>()
# ----> 1 data_train = pd.read_csv("./train.cvs")
#
# ...

# %%
data_train = pd.read_csv("/Users/lianghe/playGround/machine-learning/Titanic/train.csv")

# %%
data_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

# %%
fig.set(alpha=0.2)
# Out:
# [None]

# %%
plt.subplot2grid( (2,3),(0,0) )

# %%
data_train.Survived.value_counts().plot(kind='bar')

# %%
plt.title(u"whether survived (1 means survived)")

# %%
plt.ylabel(u"counting")

# %%
plt.subplot2grid( (2,3),(0,1) )

# %%
data_train.Pclass.value_counts().plot(kind='bar')

# %%
plt.ylabel(u"counting")

# %%
plt.title(u"passenger's class")

# %%
plt.subplot2grid( (2,3),(1,0))

# %%
plt.scatter(data_train.Survived,data_train.Age)

# %%
plt.title(u"age vs. survive")

# %%
plt.ylabel(u"age")

# %%
plt.grid(b=True,which='major',axis='y')

# %%
plt.show()
